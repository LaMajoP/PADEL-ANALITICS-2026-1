# %%
import pandas as pd

# %%
df_raw = pd.read_csv('../dataset_padel.csv')
print(f'Dataset original: {df_raw.shape[0]:,} filas, {df_raw.shape[1]} columnas')
# Out:
# Dataset original: 55,963 filas, 107 columnas

# %%
pd.set_option('display.max_columns', None)
df_raw.head()
# Out:
#      cancha    partido     punto  frame  j1_confianza  j1_x_centro  \
# 0  Cancha_1  Partido_1  Punto_10      0      0.887024        447.5
# 1  Cancha_1  Partido_1  Punto_10      3      0.891826        442.5
# 2  Cancha_1  Partido_1  Punto_10      6      0.880395        437.5
# 3  Cancha_1  Partido_1  Punto_10      9      0.873153        428.0
# 4  Cancha_1  Partido_1  Punto_10     12      0.870317        420.5
#
#    j1_y_centro  j1_hombro_d_x  j1_hombro_d_y  j1_hombro_d_confianza  \
# 0        567.5          397.0            483               0.999765
# 1        570.0          395.0            486               0.999837
# 2        569.5          392.0            488               0.999471
# 3        568.0          399.0            489               0.999255
# 4        567.5          391.0            486               0.998572
#
#    j1_codo_x  j1_codo_y  j1_codo_confianza  j1_muneca_x  j1_muneca_y  \
# 0      406.0        521           0.999017          452          545
# 1      402.0        526           0.999134          449          547
# 2      402.0        525           0.997894          448          541
# 3      404.0        533           0.996265          445          545
# 4      401.0        522           0.995766          441          542
#
#    j1_muneca_confianza  j1_punta_raqueta_x  j1_punta_raqueta_y  \
# 0             0.997493               532.0                 553
# 1             0.997012               529.0                 550
# 2             0.994462               521.0                 543
# 3             0.987716               520.0                 542
# 4             0.989314               500.0                 552
#
#    j1_punta_raqueta_confianza  j1_cabeza_x  j1_cabeza_y  j1_cabeza_confianza  \
# 0                    0.993655        382.0        429.0             0.999605
# 1                    0.991290        383.0        429.0             0.999775
# 2                    0.988133        377.0        437.0             0.999139
# 3                    0.966333        386.0        437.0             0.998971
# 4                    0.980794        371.0        437.0             0.998040
#
#    j2_confianza  j2_x_centro  j2_y_centro  j2_hombro_d_x  j2_hombro_d_y  \
# 0           NaN          NaN          NaN            NaN            NaN
# 1           NaN          NaN          NaN            NaN            NaN
# 2      0.460620        843.0        289.5          837.0          249.0
# 3      0.420058        842.0        288.5          835.0          258.0
# 4           NaN          NaN          NaN            NaN            NaN
#
#    j2_hombro_d_confianza  j2_codo_x  j2_codo_y  j2_codo_confianza  \
# 0                    NaN        NaN        NaN                NaN
# 1                    NaN        NaN        NaN                NaN
# 2               0.983409      835.0      265.0           0.974465
# 3               0.986352      836.0      274.0           0.979196
# 4                    NaN        NaN        NaN                NaN
#
#    j2_muneca_x  j2_muneca_y  j2_muneca_confianza  j2_punta_raqueta_x  \
# 0          NaN          NaN                  NaN                 NaN
# 1          NaN          NaN                  NaN                 NaN
# 2        843.0        269.0             0.953493               850.0
# 3        842.0        276.0             0.984171               851.0
# 4          NaN          NaN                  NaN                 NaN
#
#    j2_punta_raqueta_y  j2_punta_raqueta_confianza  j2_cabeza_x  j2_cabeza_y  \
# 0                 NaN                         NaN          NaN          NaN
# 1                 NaN                         NaN          NaN          NaN
# 2               246.0                    0.956057        839.0        228.0
# 3               255.0                    0.985100        834.0        241.0
# 4                 NaN                         NaN          NaN          NaN
#
#    j2_cabeza_confianza  j3_confianza  j3_x_centro  j3_y_centro  j3_hombro_d_x  \
# 0                  NaN           NaN          NaN          NaN            NaN
# 1                  NaN           NaN          NaN          NaN            NaN
# 2             0.992314           NaN          NaN          NaN            NaN
# 3             0.992441           NaN          NaN          NaN            NaN
# 4                  NaN           NaN          NaN          NaN            NaN
#
#    j3_hombro_d_y  j3_hombro_d_confianza  j3_codo_x  j3_codo_y  \
# 0            NaN                    NaN        NaN        NaN
# 1            NaN                    NaN        NaN        NaN
# 2            NaN                    NaN        NaN        NaN
# 3            NaN                    NaN        NaN        NaN
# 4            NaN                    NaN        NaN        NaN
#
#    j3_codo_confianza  j3_muneca_x  j3_muneca_y  j3_muneca_confianza  \
# 0                NaN          NaN          NaN                  NaN
# 1                NaN          NaN          NaN                  NaN
# 2                NaN          NaN          NaN                  NaN
# 3                NaN          NaN          NaN                  NaN
# 4                NaN          NaN          NaN                  NaN
#
#    j3_punta_raqueta_x  j3_punta_raqueta_y  j3_punta_raqueta_confianza  \
# 0                 NaN                 NaN                         NaN
# 1                 NaN                 NaN                         NaN
# 2                 NaN                 NaN                         NaN
# 3                 NaN                 NaN                         NaN
# 4                 NaN                 NaN                         NaN
#
#    j3_cabeza_x  j3_cabeza_y  j3_cabeza_confianza  j4_confianza  j4_x_centro  \
# 0          NaN          NaN                  NaN           NaN          NaN
# 1          NaN          NaN                  NaN           NaN          NaN
# 2          NaN          NaN                  NaN           NaN          NaN
# 3          NaN          NaN                  NaN           NaN          NaN
# 4          NaN          NaN                  NaN           NaN          NaN
#
#    j4_y_centro  j4_hombro_d_x  j4_hombro_d_y  j4_hombro_d_confianza  \
# 0          NaN            NaN            NaN                    NaN
# 1          NaN            NaN            NaN                    NaN
# 2          NaN            NaN            NaN                    NaN
# 3          NaN            NaN            NaN                    NaN
# 4          NaN            NaN            NaN                    NaN
#
#    j4_codo_x  j4_codo_y  j4_codo_confianza  j4_muneca_x  j4_muneca_y  \
# 0        NaN        NaN                NaN          NaN          NaN
# 1        NaN        NaN                NaN          NaN          NaN
# 2        NaN        NaN                NaN          NaN          NaN
# 3        NaN        NaN                NaN          NaN          NaN
# 4        NaN        NaN                NaN          NaN          NaN
#
#    j4_muneca_confianza  j4_punta_raqueta_x  j4_punta_raqueta_y  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
#    j4_punta_raqueta_confianza  j4_cabeza_x  j4_cabeza_y  j4_cabeza_confianza  \
# 0                         NaN          NaN          NaN                  NaN
# 1                         NaN          NaN          NaN                  NaN
# 2                         NaN          NaN          NaN                  NaN
# 3                         NaN          NaN          NaN                  NaN
# 4                         NaN          NaN          NaN                  NaN
#
#    j1_raqueta_sospechosa  j2_raqueta_sospechosa  j3_raqueta_sospechosa  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    j4_raqueta_sospechosa  j2_visible  j3_visible  j4_visible  \
# 0                  False           0           0           0
# 1                  False           0           0           0
# 2                  False           1           0           0
# 3                  False           1           0           0
# 4                  False           0           0           0
#
#    j1_angulo_codo_d  j1_angulo_hombro_d  j1_angulo_inclinacion_raqueta_d  \
# 0        130.877343          177.800420                       158.157782
# 1        124.001744          178.037587                       158.072087
# 2        124.303015          178.734467                       162.390347
# 3        112.796926          172.446830                       161.395538
# 4        132.089162          173.320632                       163.054677
#
#    j1_angulo_raqueta_hombro_d  j1_angulo_muneca_cabeza_d  j2_angulo_codo_d  \
# 0                  137.286722                 132.173686               NaN
# 1                  133.664314                 125.158068               NaN
# 2                  138.145905                 125.038374        109.440035
# 3                  127.110051                 116.933508        112.011283
# 4                  141.380028                 136.005086               NaN
#
#    j2_angulo_hombro_d  j2_angulo_inclinacion_raqueta_d  \
# 0                 NaN                              NaN
# 1                 NaN                              NaN
# 2          178.315316                        80.362462
# 3          179.790126                        94.763642
# 4                 NaN                              NaN
#
#    j2_angulo_raqueta_hombro_d  j2_angulo_muneca_cabeza_d  j3_angulo_codo_d  \
# 0                         NaN                        NaN               NaN
# 1                         NaN                        NaN               NaN
# 2                   33.626757                 110.394876               NaN
# 3                   44.449096                 111.903178               NaN
# 4                         NaN                        NaN               NaN
#
#    j3_angulo_hombro_d  j3_angulo_inclinacion_raqueta_d  \
# 0                 NaN                              NaN
# 1                 NaN                              NaN
# 2                 NaN                              NaN
# 3                 NaN                              NaN
# 4                 NaN                              NaN
#
#    j3_angulo_raqueta_hombro_d  j3_angulo_muneca_cabeza_d  j4_angulo_codo_d  \
# 0                         NaN                        NaN               NaN
# 1                         NaN                        NaN               NaN
# 2                         NaN                        NaN               NaN
# 3                         NaN                        NaN               NaN
# 4                         NaN                        NaN               NaN
#
#    j4_angulo_hombro_d  j4_angulo_inclinacion_raqueta_d  \
# 0                 NaN                              NaN
# 1                 NaN                              NaN
# 2                 NaN                              NaN
# 3                 NaN                              NaN
# 4                 NaN                              NaN
#
#    j4_angulo_raqueta_hombro_d  j4_angulo_muneca_cabeza_d  j1_Y_golpe  \
# 0                         NaN                        NaN         1.0
# 1                         NaN                        NaN         1.0
# 2                         NaN                        NaN         1.0
# 3                         NaN                        NaN         1.0
# 4                         NaN                        NaN         1.0
#
#    j2_Y_golpe  j3_Y_golpe  j4_Y_golpe
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         0.0         NaN         NaN
# 3         0.0         NaN         NaN
# 4         NaN         NaN         NaN

# %%
df = df_raw[['cancha','partido','punto','frame',
            'j1_angulo_codo_d', 'j1_angulo_hombro_d', 'j1_angulo_inclinacion_raqueta_d', 'j1_angulo_raqueta_hombro_d', 'j1_angulo_muneca_cabeza_d',
            'j2_angulo_codo_d', 'j2_angulo_hombro_d', 'j2_angulo_inclinacion_raqueta_d', 'j2_angulo_raqueta_hombro_d', 'j2_angulo_muneca_cabeza_d',
            'j3_angulo_codo_d', 'j3_angulo_hombro_d', 'j3_angulo_inclinacion_raqueta_d', 'j3_angulo_raqueta_hombro_d', 'j3_angulo_muneca_cabeza_d',
            'j4_angulo_codo_d', 'j4_angulo_hombro_d', 'j4_angulo_inclinacion_raqueta_d', 'j4_angulo_raqueta_hombro_d', 'j4_angulo_muneca_cabeza_d']]

print(f'df shape: {df.shape}')
df.head()
# Out:
# df shape: (55963, 24)
#      cancha    partido     punto  frame  j1_angulo_codo_d  j1_angulo_hombro_d  \
# 0  Cancha_1  Partido_1  Punto_10      0        130.877343          177.800420
# 1  Cancha_1  Partido_1  Punto_10      3        124.001744          178.037587
# 2  Cancha_1  Partido_1  Punto_10      6        124.303015          178.734467
# 3  Cancha_1  Partido_1  Punto_10      9        112.796926          172.446830
# 4  Cancha_1  Partido_1  Punto_10     12        132.089162          173.320632
#
#    j1_angulo_inclinacion_raqueta_d  j1_angulo_raqueta_hombro_d  \
# 0                       158.157782                  137.286722
# 1                       158.072087                  133.664314
# 2                       162.390347                  138.145905
# 3                       161.395538                  127.110051
# 4                       163.054677                  141.380028
#
#    j1_angulo_muneca_cabeza_d  j2_angulo_codo_d  j2_angulo_hombro_d  \
# 0                 132.173686               NaN                 NaN
# 1                 125.158068               NaN                 NaN
# 2                 125.038374        109.440035          178.315316
# 3                 116.933508        112.011283          179.790126
# 4                 136.005086               NaN                 NaN
#
#    j2_angulo_inclinacion_raqueta_d  j2_angulo_raqueta_hombro_d  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                        80.362462                   33.626757
# 3                        94.763642                   44.449096
# 4                              NaN                         NaN
#
#    j2_angulo_muneca_cabeza_d  j3_angulo_codo_d  j3_angulo_hombro_d  \
# 0                        NaN               NaN                 NaN
# 1                        NaN               NaN                 NaN
# 2                 110.394876               NaN                 NaN
# 3                 111.903178               NaN                 NaN
# 4                        NaN               NaN                 NaN
#
#    j3_angulo_inclinacion_raqueta_d  j3_angulo_raqueta_hombro_d  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
#
#    j3_angulo_muneca_cabeza_d  j4_angulo_codo_d  j4_angulo_hombro_d  \
# 0                        NaN               NaN                 NaN
# 1                        NaN               NaN                 NaN
# 2                        NaN               NaN                 NaN
# 3                        NaN               NaN                 NaN
# 4                        NaN               NaN                 NaN
#
#    j4_angulo_inclinacion_raqueta_d  j4_angulo_raqueta_hombro_d  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
#
#    j4_angulo_muneca_cabeza_d
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
df_unpivot = df.melt(
    id_vars=['cancha', 'partido', 'punto', 'frame'],
    var_name='variable',
    value_name='valor'
)

# Extraer jugador y nombre de métrica
df_unpivot['jugador'] = df_unpivot['variable'].str.extract(r'^(j\d+)_')
df_unpivot['metrica'] = df_unpivot['variable'].str.replace(r'^j\d+_', '', regex=True)

# Pivot para dejar métricas como columnas
df_final = df_unpivot.pivot_table(
    index=['cancha', 'partido', 'punto', 'frame', 'jugador'],
    columns='metrica',
    values='valor'
).reset_index()

df_final.columns.name = None
df_final = df_final.set_index(['cancha','partido','punto','frame','jugador'])
df_final.head()
# Out:
#                                           angulo_codo_d  angulo_hombro_d  \
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1          148.706961       177.816761
#                                  j2          175.351641       165.660830
#                            3     j1          151.684095       177.782584
#                                  j2          175.754804       166.631302
#                                  j3          114.443955       160.346176
#
#                                           angulo_inclinacion_raqueta_d  \
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1                         177.665114
#                                  j2                         177.340859
#                            3     j1                         175.139602
#                                  j2                         174.844416
#                                  j3                         115.750474
#
#                                           angulo_muneca_cabeza_d  \
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1                   147.601518
#                                  j2                   177.018069
#                            3     j1                   150.561748
#                                  j2                   177.142088
#                                  j3                   124.226362
#
#                                           angulo_raqueta_hombro_d
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1                    160.914850
#                                  j2                    174.791972
#                            3     j1                    160.085897
#                                  j2                    172.577217
#                                  j3                     79.005223

# %% [markdown]
# ## Preparación de datos

# %%
feature_cols = list(df_final.select_dtypes(include='number').columns)

df = df_final.dropna(subset=feature_cols)

print(f'df: {df.shape[0]:,} filas, {df.shape[1]} columnas')
df.head()
# Out:
# df: 158,213 filas, 5 columnas
#                                           angulo_codo_d  angulo_hombro_d  \
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1          148.706961       177.816761
#                                  j2          175.351641       165.660830
#                            3     j1          151.684095       177.782584
#                                  j2          175.754804       166.631302
#                                  j3          114.443955       160.346176
#
#                                           angulo_inclinacion_raqueta_d  \
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1                         177.665114
#                                  j2                         177.340859
#                            3     j1                         175.139602
#                                  j2                         174.844416
#                                  j3                         115.750474
#
#                                           angulo_muneca_cabeza_d  \
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1                   147.601518
#                                  j2                   177.018069
#                            3     j1                   150.561748
#                                  j2                   177.142088
#                                  j3                   124.226362
#
#                                           angulo_raqueta_hombro_d
# cancha   partido   punto   frame jugador
# Cancha_1 Partido_1 Punto_1 0     j1                    160.914850
#                                  j2                    174.791972
#                            3     j1                    160.085897
#                                  j2                    172.577217
#                                  j3                     79.005223

# %%
feature_cols
# Out:
# ['angulo_codo_d',
#  'angulo_hombro_d',
#  'angulo_inclinacion_raqueta_d',
#  'angulo_muneca_cabeza_d',
#  'angulo_raqueta_hombro_d']

# %% [markdown]
# ## Escalado + Elbow method

# %%
feature_cols
# Out:
# ['angulo_codo_d',
#  'angulo_hombro_d',
#  'angulo_inclinacion_raqueta_d',
#  'angulo_muneca_cabeza_d',
#  'angulo_raqueta_hombro_d']

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
X = scaler.fit_transform(df[feature_cols])

inertias = []
K_range = range(2, 11)

for k in K_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(X)
    inertias.append(km.inertia_)

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertias, marker='o')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Inercia')
plt.title('Elbow Method')
plt.xticks(K_range)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## KMeans — ajustar k según el codo

# %%
K_FINAL = 3  # ajustar según el codo

kmeans = KMeans(n_clusters=K_FINAL, random_state=42, n_init=10)
kmeans.fit(X)

df['cluster'] = kmeans.labels_
print(df['cluster'].value_counts().sort_index())
# Out:
# cluster
# 0     36288
# 1    109155
# 2     12770
# Name: count, dtype: int64

# %% [markdown]
# ## Visualización — PCA 2D

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=42)
X_2d = pca.fit_transform(X)

plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=df['cluster'], cmap='tab10', alpha=0.4, s=5)
plt.colorbar(scatter, label='Cluster')
plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)')
plt.title(f'KMeans k={K_FINAL} — proyección PCA 2D')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Media de cada variable por cluster

# %%
df.groupby('cluster')[feature_cols].mean().T
# Out:
# cluster                                0           1           2
# angulo_codo_d                 115.789078  162.488722  148.414435
# angulo_hombro_d               164.336912  165.719976  167.786715
# angulo_inclinacion_raqueta_d  143.903916  168.973989   70.446887
# angulo_muneca_cabeza_d        109.679793  161.983194  145.649294
# angulo_raqueta_hombro_d       107.414466  161.237418   51.103525

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = df.reset_index()
df[(df['cancha'] == 'Cancha_1') & 
   (df['partido'] == 'Partido_9') & 
   (df['punto'] == 'Punto_6') & 
   (df['frame'] == 690)][['cancha', 'partido', 'punto', 'frame', 'jugador', 'cluster']]
# Out:
#           cancha    partido    punto  frame jugador  cluster
# 117781  Cancha_1  Partido_9  Punto_6    690      j1        1
# 117782  Cancha_1  Partido_9  Punto_6    690      j2        1
# 117783  Cancha_1  Partido_9  Punto_6    690      j3        1
